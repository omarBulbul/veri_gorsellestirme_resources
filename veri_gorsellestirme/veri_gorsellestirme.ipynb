# %% [markdown]
# # Veriye İlk Bakış

# %%
## Veri seti hikayesinin ve yapısının incelenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# veri setinin hikayesi nedir

# %%
df=planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
#veri seti yapısal bilgileri

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
import pandas as pd
df.method=pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %% [markdown]
# ## Veri Setinin Betimlenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df=planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %% [markdown]
# ## Eksik Degerlerin Incelenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df=planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#hiç eksik gözlem(değer) var mı?

df.isnull().values.any()
# Out:
# True

# %%
#hangi değişkenlerde kaçar tane var?

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
#değişkenlerdeki N/A değerleri yerine 0 yazabiliriz. O da şöyle;

# %%
df["orbital_period"].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
#tüm eksik değerler yerine ortalama değerler atamak için;

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
df=planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.isnull().sum()

# %% [markdown]
# # Kategorik Degisken Ozetleri

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df=planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ## Sadece Kategorik Degiskenler ve Ozetleri

# %%
kat_df=df.select_dtypes(include=["object"])

# %%
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %% [markdown]
# ## Kategorik Degiskenin Siniflarina ve Sinif Sayilarina Erismek

# %%
kat_df.method.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
kat_df["method"].value_counts().count()
# Out:
# 10

# %% [markdown]
# ## Kategorik Degiskenin Siniflarinin Frekanslarina Erismek

# %%
kat_df["method"].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
df["method"].value_counts().plot.barh();

# %% [markdown]
# # Surekli Degisken Ozellikleri

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df=planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df_num=df.select_dtypes(include=["float64","int64"])
df_num.head()
# Out:
#    number  orbital_period   mass  distance  year
# 0       1         269.300   7.10     77.40  2006
# 1       1         874.774   2.21     56.95  2008
# 2       1         763.000   2.60     19.84  2011
# 3       1         326.030  19.40    110.62  2007
# 4       1         516.220  10.50    119.47  2009

# %%
df_num.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df_num["distance"].describe()
# Out:
# count     808.000000
# mean      264.069282
# std       733.116493
# min         1.350000
# 25%        32.560000
# 50%        55.250000
# 75%       178.500000
# max      8500.000000
# Name: distance, dtype: float64

# %%
print("Ortalama: " + str(df_num["distance"].mean()))
print("Dolu Gozlem Sayisi: " + str(df_num["distance"].count()))
print("Maksimum Deger: " + str(df_num["distance"].max()))
print("Minimum Deger: " + str(df_num["distance"].min()))
print("Medyan: " + str(df_num["distance"].median()))
print("Standart Sapma: " + str(df_num["distance"].std()))
# Out:
# Ortalama: 264.06928217821786
# Dolu Gozlem Sayisi: 808
# Maksimum Deger: 8500.0
# Minimum Deger: 1.35
# Medyan: 55.25
# Standart Sapma: 733.1164929404422

# %% [markdown]
# # Dağılım Grafikleri

# %% [markdown]
# ## Barplot(sütun grafiği)

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ### veri setine hızlı bakış

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df["color"].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
#ordinal tanımlama
from pandas.api.types import CategoricalDtype

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut=df.cut.astype(CategoricalDtype(ordered = True))

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Ideal' < 'Premium' < 'Very Good' < 'Good' < 'Fair']

# %%
cut_kategoriler = ["Fair","Good","Very Good","Premium","Ideal"]

# %%
df.cut=df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
#barplot

# %%
df["cut"].value_counts().plot.barh().set_title("Cut Değişkeninin Sınıf Frekansları");

# %%
#üstteki kod uzun olduğu için şöyle de yazabiliriz.

# %%
(df["cut"]
 .value_counts()
 .plot.barh()
 .set_title("Cut Değişkeninin Sınıf Frekansları"));

# %%
# yukarıda yaptıklarımız pandas ile görselleştirmeydi ama biz seabornu kullanaacğız

# %%
sns.barplot(x="cut", y=df.cut.index, data=df);

# %% [markdown]
# # Çaprazlamalar

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
diamonds = sns.load_dataset("diamonds")
df=diamonds.copy()
cut_kategoriler = ["Fair","Good","Very Good","Premium","Ideal"]
df.cut=df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#catplot kategorik değişkenleri görselleştirmek için kullanılan bir fonksiyondur.

# %%
sns.catplot(x = "cut", y = "price", data=df);

# %%
# boyut eklemeyi hue argümanıyla yaparız

# %%
sns.barplot(x="cut",y="price",hue="color",data=df);

# %%
df.groupby(["cut","color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %% [markdown]
# # Histogram ve Yoğunluk Grafiği

# %%
import seaborn as sns
diamonds=sns.load_dataset("diamonds")
df=diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#hisyogram ve yoğunluk grafikleri sayısal değişkenler için kullanılan 
#sayısal değişkenlerin dağılımını ifade eden veri görselleştirme tektiklerinden biridir

# %%
sns.distplot(df.price, kde = False);
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
# ?sns.distplot
# Out:
# Signature:
# sns.distplot(
#     a=None,
#     bins=None,
#     hist=True,
#     kde=True,
#     rug=False,
#     fit=None,
#     hist_kws=None,
#     kde_kws=None,
#     rug_kws=None,
#     fit_kws=None,
#     color=None,
#     vertical=False,
#     norm_hist=False,
#     axlabel=None,
#     label=None,
#     ax=None,
#     x=None,
# )
# Docstring:
# DEPRECATED: Flexibly plot a univariate distribution of observations.
#
# .. warning::
#    This function is deprecated and will be removed in a future version.
#    Please adapt your code to use one of two new functions:
#
#    - :func:`displot`, a figure-level function with a similar flexibility
#      over the kind of plot to draw
#    - :func:`histplot`, an axes-level function for plotting histograms,
#      including with kernel density smoothing
#
# This function combines the matplotlib ``hist`` function (with automatic
# calculation of a good default bin size) with the seaborn :func:`kdeplot`
# ...

# %%
sns.distplot(df.price, bins=10, kde = False);

# %%
#kde argümanı yoğunluk belirtmek için kullanılır.

# %%
sns.distplot(df.price);

# %%
# histogramı değil de sadece yoğunluğu görmek istersek şöyle yapıyoruz

# %%
sns.distplot(df.price, hist=False);
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df.price, shade = True);

# %%
#yoğunluğun altını doldurmak için shade argümanını True yaptık

# %% [markdown]
# ## Çaprazlamalar

# %%
import seaborn as sns
diamonds=sns.load_dataset("diamonds")
df=diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.kdeplot(df.price, shade=True);

# %%
# facetGrid grafik üzerine eklenen boyutları bölerek göstermek için kullanılır.

# %%
(sns
 .FacetGrid(df,
              hue="cut",
              height=5,
              xlim = (0, 10000))
 .map(sns.kdeplot, "price", shade=True)
 .add_legend()
);

# %%
sns.catplot(x="cut", y="price", hue="color", kind="point", data=df);

# %% [markdown]
# # Boxplot

# %% [markdown]
# ### Veri Seti Hikayesi

# %% [markdown]
# total_bill: yemeğin toplam fiyatı(bahşiş ve vergi dahil)
#
# tip: bahşiş
#
# sex: ücreti ödeyen kişinin cinsiyeti(0=male, 1=female)
#
# smoker: grupta sigara içen var mı? (0=no, 1=yes)
#
# day:gün(3=thur, 4=fri, 5=sat, 6=sun)
#
# time:ne zaman(0=day, 1=night)
#
# size: grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = df["total_bill"]);

# %% [markdown]
# ## Çaprazlamalar

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
#Hangi gunler daha fazla kazanıyoruz?

# %%
sns.boxplot(x = "day", y = "total_bill", data=df);

# %%
#sabah mı akşam mı daha çok kazanıyoruz?

# %%
sns.boxplot(x = "time", y="total_bill", data=df);

# %%
# yemege gelen grup sayisi ile kazancin dogru orantili olup olmadigini inceleyelim

# %%
sns.boxplot(x = "size", y="total_bill", data=df);

# %%
sns.boxplot(x = "day", y="total_bill", hue="sex", data=df);

# %% [markdown]
# # Violin Grafiği

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y = "total_bill", kind ="violin", data=df);

# %% [markdown]
# ## Çaprazlamalar

# %%
sns.catplot(x="day", y = "total_bill", kind ="violin", data=df);

# %%
#bunlara bir kırılım(boyut eklemek) daha ekleyelim hem günlere göre hem de ödeme yapan kişinin cinsiyetine göre

# %%
sns.catplot(x="day", y = "total_bill", hue="sex", kind ="violin", data=df);

# %% [markdown]
# # Korelasyon Grafikleri

# %% [markdown]
# ## Scatterplot

# %% [markdown]
# total_bill: yemeğin toplam fiyatı(bahşiş ve vergi dahil)
#
# tip: bahşiş
#
# sex: ücreti ödeyen kişinin cinsiyeti(0=male, 1=female)
#
# smoker: grupta sigara içen var mı? (0=no, 1=yes)
#
# day:gün(3=thur, 4=fri, 5=sat, 6=sun)
#
# time:ne zaman(0=day, 1=night)
#
# size: grupta kaç kişi var?

# %%
import seaborn as sns 
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# korelasyon değişkenler arasındaki ilişkiyi ifade eden istatiksel bir terimdir

# %%
sns.scatterplot(x="total_bill", y="tip", data=df);

# %% [markdown]
# ## Çaprazlamalar

# %%
sns.scatterplot(x="total_bill", y="tip", hue="time", data=df);

# %%
sns.scatterplot(x="total_bill", y="tip", hue="time", style="time", data=df);

# %%
#kategorik değişkenleri boyut olarak eklemek istersek

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", style="time", data=df);

# %%
#sürekli değişkeni boyut olarak eklemek istersek

# %%
sns.scatterplot(x="total_bill", y="tip",hue="size",size = "size", data=df);

# %% [markdown]
# # Doğrusal İlişkinin Gösterilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill", y="tip", data=df);

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker", data=df);

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",col="time", data=df);

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",col="time",row="sex", data=df);

# %% [markdown]
# # Scatterplot Matrisi

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
df = iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df, hue="species");

# %%
sns.pairplot(df, hue="species", markers=["o","s","D"]);

# %%
sns.pairplot(df, kind="reg");

# %%
sns.pairplot(df, kind="reg",hue="species");

# %% [markdown]
# # Heatmap (Isı Haritası)

# %% [markdown]
# ## Veri Seti Hikayesi

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
df=flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df["passengers"].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
df = df.pivot("month", "year", "passengers");

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df);

# %%
sns.heatmap(df, annot = True, fmt="d");

# %%
sns.heatmap(df, annot = True, fmt="d",linewidths = .5);

# %% [markdown]
# # Çizgi Grafik

# %% [markdown]
# ## Veri Seti Hikayesi

# %%
import seaborn as sns 
fmri = sns.load_dataset("fmri")
df=fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
#amacımız her bir zaman noktasına göre signalin durumunu gözlemlemek olsun ve sonrasında çaprazlama işlemleri ile birlikte buradaki diğer değişkenleri boyut olarak veri setine eklemek olsun

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
#her bir zaman noktasında acaba eşit sinyal mı var?

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %% [markdown]
# ## Çizgi Grafik ve Çaprazlamalar

# %%
sns.lineplot(x = "timepoint", y = "signal", data=df);

# %%
sns.lineplot(x = "timepoint", y = "signal",hue="event", data=df);

# %%
sns.lineplot(x = "timepoint", y = "signal",hue="event", style="event", data=df);

# %%
sns.lineplot(x = "timepoint",
             y = "signal",
             hue="event",
             style="event",
             markers= True,
             dashes = False,
             data=df);

# %%
sns.lineplot(x = "timepoint",
             y = "signal",
             hue="region",
             style="event",
             data=df);

# %% [markdown]
# # Basit Zaman Serisi Grafiği

# %%
# !pip install pandas_datareader
import pandas_datareader as pr
import pandas as pd

# %%
#apple'ın borsadaki hisse senedi değerleri veri setimiz olacak

# %%
df = pr.get_data_yahoo("AAPL", start="2016-01-01",end="2019-08-25")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.251436
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.643711
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.181007
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.202669
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.320072

# %%
df.shape
# Out:
# (917, 6)

# %%
kapanis = df["Close"]

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanis.plot();

# %%
kapanis.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanis.plot();
